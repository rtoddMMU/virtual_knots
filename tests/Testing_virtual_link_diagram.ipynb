# %%
from vkt.core import Crossing, StrandRef, connect, disconnect
from vkt.core import parse_gauss_code, VirtualLink, VirtualLinkDiagram

# %%
c0=Crossing(kind="classical", sign= -1, id= 0)
c1=Crossing(kind="virtual",id=1)
c2=Crossing(kind="classical",sign=-1,id=2)

# %%
connect(c0.ref(0), c1.ref(0))
connect(c0.ref(1), c1.ref(1))
connect(c1.ref(0), c2.ref(0))
connect(c1.ref(1), c2.ref(1))
connect(c2.ref(0), c0.ref(1))
connect(c2.ref(1), c0.ref(0))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 connect(c0.ref(0), c1.ref(0))
#       2 connect(c0.ref(1), c1.ref(1))
#       3 connect(c1.ref(0), c2.ref(0))
#       4 connect(c1.ref(1), c2.ref(1))
#
# File ~\virtual_knots\src\vkt\core\crossing.py:99, in connect(a, b)
#      97 def connect(a: StrandRef, b: StrandRef) -> None:
#      98     if a.crossing.next[a.strand] is not None:
# ---> 99         raise RuntimeError("next already set")
#     100     if b.crossing.prev[b.strand] is not None:
#     101         raise RuntimeError("prev already set")
#
# RuntimeError: next already set
